# %%
from google.colab import files
from IPython.display import Image
from PIL import Image
import numpy as np

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-349aca6d-1a83-4ce2-a57c-28bbd828edd4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-349aca6d-1a83-4ce2-a57c-28bbd828edd4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 20069.jpg to 20069 (1).jpg

# %%
img = Image.open("20069 (1).jpg")
img.show()
print(img.format)
img1 = np.asarray(img)
print(type(img1))
# Out:
# JPEG
# <class 'numpy.ndarray'>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread("20069 (1).jpg")
print(type(img))
print(img.shape)
plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# (481, 321, 3)

# %%
from skimage import io,img_as_float,img_as_ubyte
import matplotlib.pyplot as plt
image = io.imread("20069 (1).jpg")
plt.imshow(image)
image_f = img_as_float(image) # converts image to float (pixel/256)
# print(image_f,end=" ")

# %%
import cv2
from matplotlib import pyplot as plt
img2 = cv2.imread("20069 (1).jpg",1) # 0 for gray as 1 for color but the original color of image is changed
plt.imshow(img2)

# %%
from google.colab.patches import cv2_imshow
gray_img = cv2.imread("20069 (1).jpg",0)
color_img = cv2.imread("20069 (1).jpg",1) # here it will show original image
cv2_imshow(gray_img)
cv2_imshow(color_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=321x481 at 0x7FD2A3D24990>
# <PIL.Image.Image image mode=RGB size=321x481 at 0x7FD2A3D24990>
