# %%
class Building:
    
    def __init__(self, number):
        self.number = number

b = Building(245)

b.number
# Out:
# 245

# %%
d = { 'one': 1,'two': 2,'three': 3,'four': 4}
d['two']
# Out:
# 2

# %%
i=0
while i<10:
print(i)
i= i+1
# Out:
#   File "<ipython-input-3-fbbfad4e0c48>", line 3
#     print(i)
#         ^
# IndentationError: expected an indented block

# %%
g = lambda x, y: x + y

g(2,3)
# Out:
# 5

# %%
class Dog:    
    def woof(self):
        return 'woof!'

t = Dog()
t.woof()
# Out:
# 'woof!'

# %%
with open('hello.txt', 'w') as file:
  file.write("hello!")

print(file.closed)
# Out:
# True

# %%
class Candy(): 
  flavor = 'sweet'
  def __init__(self, name):
        self.name = name
        
c = Candy('Chocolate')

c.name
# Out:
# 'Chocolate'

# %%
boardgames = [
  'Pandemic Legacy: Season 1', 
  'Terraforming Mars', 
  'Brass: Birmingham'
]

boardgames.insert(0, 'Gloomhaven')

print(boardgames)
# Out:
# ['Gloomhaven', 'Pandemic Legacy: Season 1', 'Terraforming Mars', 'Brass: Birmingham']

# %%
w = 'python'

w_iterator = iter(w)

next(w_iterator)
# Out:
# 'p'

# %%
x = (1, 2, 3)
s = dict.fromkeys(x)

s
# Out:
# {1: None, 2: None, 3: None}

# %%
import numpy as np

samples = np.random.poisson(10, 100)


print(samples)
# Out:
# [ 7  9  7  8 11  7 14  7  9 11  7 10  7  8 11  9 12 11  9 16 16  6 12 10
#   5  2 11 11 14  5 12  8 10  5  6  8 16  7  9 10 11 11 15 10  8 14  9  9
#  10  8  6  9 14  9 11  8 13 11  5 13 10 11  9  9 14 10 10  6  9 13 10 10
#   7  8 10  8 13  7 11 10 11 10  8 11 17  8  9  6  9 13  7  9 19 16 13 11
#   8  7  5  7]

# %%
import numpy as np
bootstraps = [20, 2, 7, 1, 34]

lower = np.quantile(bootstraps, 0.025)
upper = np.quantile(bootstraps, 0.975)

print(f"""Lower bound: {round(lower, 2)}\n
Upper bound: {round(upper, 2)}""")
# Out:
# Lower bound: 1.1
#
# Upper bound: 32.6

# %%
import numpy as np

samples= np.random.normal(size = 10000)


print(samples)
# Out:
# [ 0.8259208   1.99388841  0.22887346 ... -0.97800566 -1.23929213
#   0.07786252]

# %%
import numpy as np

norm = np.random.normal(50, 5, 100)

print(f"""Sample size: {round(len(norm), 2)}
Sample mean: {round(np.mean(norm), 2)} 
Sample SD: {round(np.std(norm), 2)}""")
# Out:
# Sample size: 100
# Sample mean: 50.07
# Sample SD: 5.35

# %%
import numpy as np

seed = 42

sample = np.random.randint(0, 11, 5)
print(sample)
# Out:
# [10  0  1  2  3]

# %%
# Create an array of 100 numbers sampled from a Binomial distribution with 10 trials and a probability of success of 0.5

import numpy as np
from scipy.stats import binom

sample = np.random.binomial(10, 0.5, 100)

print(sample)
# Out:
# [7 3 3 6 6 4 3 8 3 1 4 4 6 5 4 6 7 5 3 6 7 6 5 4 6 4 7 7 5 7 5 6 6 5 5 5 5
#  3 6 6 6 9 5 6 7 6 3 6 6 4 4 5 5 5 4 8 6 6 8 7 7 4 6 2 3 3 6 7 6 4 7 1 4 4
#  5 5 8 5 8 5 6 6 5 9 5 6 7 5 4 3 4 6 3 5 5 6 4 4 8 7]

# %%
# Sample with replacement from the data array. The size of the sample should be equal to the data array. The random seed has been set for you.

data = np.array([13, 28, 56, 31, 63])

sample = np.random.choice(data, 5)
print(sample)
# Out:
# [31 56 56 28 63]

# %%
# Create an array of 100 numbers sampled from a Poisson distribution were the observed interval is equal to 5. The random seed has been set for you.

import numpy as np
from scipy.stats import poisson

sample = np.random.poisson(lam=5, size = 100)
print(sample)
# Out:
# [ 6  5  6  9  6  6  4  9  5  4  5  7  3  5  3  0  5  7  3  4  8  9  3  7
#   4  7  2  5 10  2  4  2  4  4  7  7  5  2  7  7  7  4  4  8  4  4  4  8
#   4  6  4  5  4  2  3  5  8  5  4  7  3  2  6  7  3  5  5  3  3  6  8  7
#   5  4  6  4  5  6  4  2  4  9  4  7  2  4  7  3  5  8  1  5  4  4  4  3
#   6  3  4  7]

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, 'bo')

# %%
plt.plot(ys)

# %%
plt.plot(ys, 'r+')

# %%
plt.plot(x, ys, color='green', marker='o', linestyle='dashed', linewidth=1, markersize=2)

# %%
plt.plot(x, ys, '-,')

# %%
import numpy as np
import matplotlib.pyplot as plt

p = np.arange(0.0, 10, 0.05)
s1 = np.sin(2*np.pi*p)
s2 = np.cos(2*np.pi*p)

# %%
plt.figure(1)
plt.subplot(211)
plt.plot(p, s1)
plt.subplot(212)
plt.plot(p, 10*s2)

# %%
x = (1, 2, 3)
s = tuple(x)

s
# Out:
# (1, 2, 3)

# %%
class Person:
    def __init__(self, name):
        self.name = name

m = Person('Michael')

m.name
# Out:
# 'Michael'

# %%
# Complete the statement using a list comprehension such that it matches the output.
[x.upper() for x in ['hello', 'world']]
# Out:
# ['HELLO', 'WORLD']

# %%
# Complete the code to return the output
def add_many(*args):
    s = 0
    for n in args:
        s += n
    print(s)

add_many(100, 50, 3)
# Out:
# 153

# %%
def myfunc(*args):
    out = []
    for num in args:
        if num%2==0:
            out.append(num)
    return out

# %%
myfunc(11, 12,25,55)
# Out:
# [12]

# %%
x = (i for i in range(5))

next(x)
# Out:
# 0

# %%
string = "Medical image classification using machine learning and deep learning "
string.upper()
# Out:
# 'MEDICAL IMAGE CLASSIFICATION USING MACHINE LEARNING AND DEEP LEARNING '

# %%
# Definition of radius
r = 192500

# Import radians function of math package
from math import radians

# Travel distance of Moon over 12 degrees. Store in dist.
dist = r * radians(12)

# Print out dist
print(dist)
# Out:
# 40317.10572106901

# %%
import numpy as np
height = np.round(np.random.normal(1.75, 0.20, 5000), 2)
weight = np.round(np.random.normal(60.50, 15, 5000), 2)

# %%
np_city = np.column_stack((height, weight))
np_city
# Out:
# array([[ 1.8 , 43.7 ],
#        [ 1.32, 78.29],
#        [ 1.95, 55.78],
#        ...,
#        [ 1.34, 37.07],
#        [ 1.62, 72.77],
#        [ 1.63, 83.17]])

# %%
d = {
    'one': 1,
    'two': 2,
    'three': 3,
    'four': 4
}

d['two']
# Out:
# 2

# %%
# Access the docstrings of the factorial() function.
def factorial(n):
  """returns n!"""
  return 1 if n < 2 else n * factorial(n-1)
factorial.__doc__
# Out:
# 'returns n!'

# %%
# Decorate the adder() and subtractor functions so that the result of the adder function is multiplied by 2 and the result of the subtract function is multiplied by 3.

def multiply(by = None):
	def multiply_real_decorator(function):
		def wrapper(*args,**kwargs):
			return by * function(*args,**kwargs)
		return wrapper
	return multiply_real_decorator

multiply(by = 2)

def adder(a,b):
  return a + b

write code here

def adder(a,b):
  return a + b

write code here

def subtractor(a,b):
  return a - b

print(adder(2,3))
print(subtractor(2,3))
# Out:
# 5

# %%
multiply(by = 2)
multiply_real_decoder(adder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f714f7149faf> in <module>()
#       1 multiply(by = 2)
# ----> 2 multiply_real_decoder(adder)
#
# NameError: name 'multiply_real_decoder' is not defined

# %%
a = int(input())
b = int(input())
s = a + b
print(s)
# Out:
# 10
# 21
# 31

# %%
a = int(input())
b = int(input())
c = int(input())

d = c - b
print(d)
# Out:
# 10
# 15
# 20
# 5

# %%
n = int(input())
if n < 0:
   print("Enter a positive number")
else:
   sum = 0
while (n > 0):
  sum += n 
  n -= 1  
print("The result is",sum)
# Out:
# 10
# The result is 55

# %%
N = int(input())

sum = 0
num = 1

while (num <= N):
  num = num + 1
  if(num%2 == 0):
    sum += num

print(sum)
# Out:
# 4
# 6

# %%
n = int(input())

d = 2
flag = False
while d < n:
  if (n%d == 0):
    flag = True
  d = d + 1

if flag:
  print("not prime")

else:
  print("prime")
# Out:
# 11
# prime

# %%
S = int(input())
E = int(input())
W = int(input())

while (S <= E):
    c = int((S - 32) * (5/9))
    print(str(S) + "\t" + str(c))
    S = S + W
# Out:
# 0
# 100
# 20
# 0	-17
# 20	-6
# 40	4
# 60	15
# 80	26
# 100	37

# %%
class Planet:
    def __init__(self, name):
        self.name = name
        
v= Planet('venus')
v.name
# Out:
# 'venus'

# %%
class Planet:
    def __init__(self, name, diameter_km):
        self.name = name
        self.diameter_km = diameter_km
        
e = Planet('earth',12225)


e.name, e.diameter_km
# Out:
# ('earth', 12225)

# %%
[i for i%2==0 in range(5)]
# Out:
#   File "<ipython-input-8-c3c196ce48a5>", line 1
#     [i for i%2==0 in range(5)]
#                ^
# SyntaxError: invalid syntax
