# %%
import pandas as pd

df = pd.DataFrame(
    {
        "Name": [
            "pradeep deshmukh",
            "ms seema chaudary",
            "ramshankar prasad"],
        "Age": [22, 28, 21], 
        "Gender": ["male", "male", "female"],
    }
)

# %%
df.columns = ["name of a person", "Age of person", "Gender"]
df
# Out:
#     name of a person  Age of person  Gender
# 0   pradeep deshmukh             22    male
# 1  ms seema chaudary             28    male
# 2  ramshankar prasad             21  female

# %%
df = pd.DataFrame(
   ...:     {
   ...:         "Name": [
   ...:             "Braund, Mr. Owen Harris",
   ...:             "Allen, Mr. William Henry",
   ...:             "Bonnell, Miss. Elizabeth",
   ...:         ],
   ...:         "Age": [22, 35, 58],
   ...:         "Sex": ["male", "male", "female"],
   ...:     }
   ...: )

# %%
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
data["Age"]
# Out:
# 0    22
# 1    28
# 2    21
# Name: Age, dtype: int64

# %%
df["Sex"]
# Out:
# 0      male
# 1      male
# 2    female
# Name: Sex, dtype: object

# %%
df["Age"].min()
# Out:
# 22

# %%
data["Age"].sum()
# Out:
# 71

# %%
data.describe()
# Out:
#              Age
# count   3.000000
# mean   23.666667
# std     3.785939
# min    21.000000
# 25%    21.500000
# 50%    22.000000
# 75%    25.000000
# max    28.000000

# %%
import pandas as pd
Proj1 = pd.read_excel("Downloads/KGP/Project sem1/project sheet.xlsx")

# %%
Proj1
# Out:
#    DATA NO  LEAD  P WAVE MAGNITUDE  Q WAVE MAGNITUDE  R WAVE MAGNITUDE  \
# 0     100M   ML2            0.0826           -0.1616            0.9023
# 1     101M   ML2            0.0957           -0.0512            0.5203
# 2     105M   ML2            0.1235            0.0423            0.8950
# 3     111M   ML2            0.3951            0.1445            0.7492
# 4     112M   ML2            0.1487           -0.0031            0.6918
# 5     113M   ML2            0.0246           -0.0307            0.4519
# 6     106M   ML2            0.1392           -0.0712            0.9787
# 7     114M   ML2            0.2407            0.0436            0.8620
# 8     115M   ML2            0.0451           -0.2194            0.9349
# 9     116M   ML2            0.0600           -0.2594            0.9127
# 10    117M   ML2            0.1333           -0.0085            0.9299
# 11    118M   ML2            0.3494           -0.1024            0.7856
# ...

# %%
Proj1['QRS INTERVAL'].max()
# Out:
# 0.304

# %%
Proj1['DATA NO'][Proj1['GENDER']=='F']
# Out:
# 1       101M
# 2       105M
# 3       111M
# 5       113M
# 6       106M
# 7       114M
# 8       115M
# 12      119M
# 13      121M
# 15      123M
# 21      207M
# 24      212M
# 31    16272M
# 32    16273M
# 33    16420M
# 35    16539M
# 37    16786M
# 38    17052M
# 39    17453M
# 40    18184M
# 41    19088M
# 42    19090M
# 44    19140M
# 45    19830M
# 47    16272M
# 48    16420M
# 50    18184M
# 51    19088M
# 52    19830M
# 53    19140M
# 54    19090M
# Name: DATA NO, dtype: object

# %%
Proj1.fillna(0, inplace= True)

# %%
data = pd.read_csv("Downloads/dataset/Amazon_Best_Seller_2021_June.csv")

# %%
data
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link No of Sellers Rank  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...     1 Sellers   #1
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...     1 Sellers   #2
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...     1 Sellers   #3
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...    27 Sellers   #4
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...     1 Sellers   #5
# ..                                                 ...           ...  ...
# 702  https://www.amazon.com/gp/offer-listing/B007DW...    10 Sellers  #95
# ...

# %%
new_data = data.replace({
    'No of Sellers': '[A-Za-z]',
    'Rank': '#',
    'Price': '[$]',
},'',regex=True)
new_data
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link No of Sellers Rank  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...            1     1
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...            1     2
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...            1     3
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...           27     4
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...            1     5
# ..                                                 ...           ...  ...
# 702  https://www.amazon.com/gp/offer-listing/B007DW...           10    95
# ...

# %%
rows, columns = data.shape

# %%
rows
# Out:
# 707

# %%
columns
# Out:
# 8

# %%
data.head(5)
# Out:
#          ASIN     Category                                       Product Link  \
# 0  B079QHML21  Electronics  https://www.amazon.com/gp/offer-listing/B079QH...
# 1  B07FZ8S74R  Electronics  https://www.amazon.com/gp/offer-listing/B07FZ8...
# 2  B07XJ8C8F5  Electronics  https://www.amazon.com/gp/offer-listing/B07XJ8...
# 3  B07WVFCVJN  Electronics  https://www.amazon.com/gp/offer-listing/B07WVF...
# 4  B08YT2N5SX  Electronics  https://www.amazon.com/gp/offer-listing/B08YT2...
#
#   No of Sellers Rank  Rating Reviews Count    Price
# 0     1 Sellers   #1     4.7       640,721  $39.99
# 1     1 Sellers   #2     4.7       854,114  $34.99
# 2     1 Sellers   #3     4.7       267,821  $44.99
# 3    27 Sellers   #4     4.8       114,267  $28.48
# 4     1 Sellers   #5     4.7       267,821  $49.99

# %%
data[3:8]
# Out:
#          ASIN     Category                                       Product Link  \
# 3  B07WVFCVJN  Electronics  https://www.amazon.com/gp/offer-listing/B07WVF...
# 4  B08YT2N5SX  Electronics  https://www.amazon.com/gp/offer-listing/B08YT2...
# 5  B07TMJ1R3X  Electronics  https://www.amazon.com/gp/offer-listing/B07TMJ...
# 6  B07X6C9RMF  Electronics  https://www.amazon.com/gp/offer-listing/B07X6C...
# 7  B08BX7FV5L  Electronics  https://www.amazon.com/gp/offer-listing/B08BX7...
#
#   No of Sellers Rank  Rating Reviews Count     Price
# 3    27 Sellers   #4     4.8       114,267   $28.48
# 4     1 Sellers   #5     4.7       267,821   $49.99
# 5     1 Sellers   #6     4.6       100,278   $89.99
# 6     1 Sellers   #7     4.5       111,650   $34.99
# 7     1 Sellers   #8     4.5         1,228  $149.99

# %%
data.columns
# Out:
# Index(['ASIN', 'Category', 'Product Link', 'No of Sellers', 'Rank', 'Rating',
#        'Reviews Count', 'Price'],
#       dtype='object')

# %%
type(data['No of Sellers'])
# Out:
# pandas.core.series.Series

# %%
data[['Rank','Rating','Price']]
# Out:
#     Rank  Rating    Price
# 0     #1     4.7  $39.99
# 1     #2     4.7  $34.99
# 2     #3     4.7  $44.99
# 3     #4     4.8  $28.48
# 4     #5     4.7  $49.99
# ..   ...     ...      ...
# 702  #95     4.6   $6.99
# 703  #96     4.7  $16.99
# 704  #97     4.8   $8.99
# 705  #98     4.7  $19.99
# 706  #99     4.7  $24.99
#
# [707 rows x 3 columns]

# %%
data['Price'].max()
# Out:
# '$99.99 '

# %%
data.describe()
# Out:
#            Rating
# count  707.000000
# mean     4.593494
# std      0.284117
# min      1.400000
# 25%      4.500000
# 50%      4.700000
# 75%      4.800000
# max      5.000000

# %%
data[data.Rating>= 4.9]
# Out:
#            ASIN        Category  \
# 45   B08J61NFNR     Electronics
# 49   B095NWYQBC     Electronics
# 77   B08J65DST5     Electronics
# 82   B08YMBQJ49     Electronics
# 92   B08J5Q255V     Electronics
# ..          ...             ...
# 515  B095NWYQBC  Camera & Photo
# 623  B07P6MZPK3    Toys & Games
# 629  B00000IV35    Toys & Games
# 642  B078VVLQ6J    Toys & Games
# 677  B00000IVAK    Toys & Games
#
#                                           Product Link No of Sellers Rank  \
# 45   https://www.amazon.com/gp/offer-listing/B08J61...     6 Sellers  #47
# 49   https://www.amazon.com/gp/offer-listing/B095NW...     1 Sellers  #51
# 77   https://www.amazon.com/gp/offer-listing/B08J65...     6 Sellers  #79
# 82   https://www.amazon.com/gp/offer-listing/B08YMB...     1 Sellers  #85
# 92   https://www.amazon.com/gp/offer-listing/B08J5Q...     5 Sellers  #95
# ..                                                 ...           ...  ...
# ...

# %%
data.set_index('ASIN', inplace= True)

# %%
data
# Out:
#                 Category                                       Product Link  \
# ASIN
# B079QHML21   Electronics  https://www.amazon.com/gp/offer-listing/B079QH...
# B07FZ8S74R   Electronics  https://www.amazon.com/gp/offer-listing/B07FZ8...
# B07XJ8C8F5   Electronics  https://www.amazon.com/gp/offer-listing/B07XJ8...
# B07WVFCVJN   Electronics  https://www.amazon.com/gp/offer-listing/B07WVF...
# B08YT2N5SX   Electronics  https://www.amazon.com/gp/offer-listing/B08YT2...
# ...                  ...                                                ...
# B007DW6F34  Toys & Games  https://www.amazon.com/gp/offer-listing/B007DW...
# B01N16VX79  Toys & Games  https://www.amazon.com/gp/offer-listing/B01N16...
# B09197N995  Toys & Games  https://www.amazon.com/gp/offer-listing/B09197...
# B015CCR1FW  Toys & Games  https://www.amazon.com/gp/offer-listing/B015CC...
# B07TS96J7Q  Toys & Games  https://www.amazon.com/gp/offer-listing/B07TS9...
#
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link No of Sellers Rank  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...     1 Sellers   #1
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...     1 Sellers   #2
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...     1 Sellers   #3
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...    27 Sellers   #4
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...     1 Sellers   #5
# ..                                                 ...           ...  ...
# 702  https://www.amazon.com/gp/offer-listing/B007DW...    10 Sellers  #95
# ...

# %%
data.set_index('No of Sellers',inplace=True)

# %%
data
# Out:
#                      ASIN      Category  \
# No of Sellers
# 1 Sellers      B079QHML21   Electronics
# 1 Sellers      B07FZ8S74R   Electronics
# 1 Sellers      B07XJ8C8F5   Electronics
# 27 Sellers     B07WVFCVJN   Electronics
# 1 Sellers      B08YT2N5SX   Electronics
# ...                   ...           ...
# 10 Sellers     B007DW6F34  Toys & Games
# 5 Sellers      B01N16VX79  Toys & Games
# 1 Sellers      B09197N995  Toys & Games
# 26 Sellers     B015CCR1FW  Toys & Games
# 2 Sellers      B07TS96J7Q  Toys & Games
#
#                                                     Product Link Rank  Rating  \
# No of Sellers
# 1 Sellers      https://www.amazon.com/gp/offer-listing/B079QH...   #1     4.7
# 1 Sellers      https://www.amazon.com/gp/offer-listing/B07FZ8...   #2     4.7
# 1 Sellers      https://www.amazon.com/gp/offer-listing/B07XJ8...   #3     4.7
# 27 Sellers     https://www.amazon.com/gp/offer-listing/B07WVF...   #4     4.8
# ...

# %%
data.loc['10 Sellers']
# Out:
#                      ASIN                   Category  \
# No of Sellers
# 10 Sellers     B08DFCWVZ4                Electronics
# 10 Sellers     B081RJ8DW1                Electronics
# 10 Sellers     B08DFCWVZ4                Electronics
# 10 Sellers     B081RJ8DW1                Electronics
# 10 Sellers     B086KXKXKW  Clothing, Shoes & Jewelry
# 10 Sellers     B00Z0UWV98                Video Games
# 10 Sellers     B00YXO5U40                Video Games
# 10 Sellers     B081RJ8DW1             Camera & Photo
# 10 Sellers     B08GH9KL4M             Camera & Photo
# 10 Sellers     B00005C5H4               Toys & Games
# 10 Sellers     B007DW6F34               Toys & Games
#
#                                                     Product Link Rank  Rating  \
# No of Sellers
# 10 Sellers     https://www.amazon.com/gp/offer-listing/B08DFC...  #59     4.4
# 10 Sellers     https://www.amazon.com/gp/offer-listing/B081RJ...  #62     4.4
# ...

# %%
weather_data= [
    ('1/2/2014',32,8,'snow'),
    ('2/4/2016',35,6,'rainy'),
    ('2/2/2016',40,7,'sunny')
]

data = pd.DataFrame(weather_data, columns = ["day","temp","wind","event"])
data
# Out:
#         day  temp  wind  event
# 0  1/2/2014    32     8   snow
# 1  2/4/2016    35     6  rainy
# 2  2/2/2016    40     7  sunny

# %%
# DF = pd.read_csv("Downloads\dataset\Real estate.csv", header=None)
DF = pd.read_csv("Downloads\dataset\Real estate.csv")

# %%
DF.set_index('X1 transaction date',inplace=True)
DF
# Out:
#                       No  X2 house age  \
# X1 transaction date
# 2012.917               1          32.0
# 2012.917               2          19.5
# 2013.583               3          13.3
# 2013.500               4          13.3
# 2012.833               5           5.0
# ...                  ...           ...
# 2013.000             410          13.7
# 2012.667             411           5.6
# 2013.250             412          18.8
# 2013.000             413           8.1
# 2013.500             414           6.5
#
#                      X3 distance to the nearest MRT station  \
# X1 transaction date
# 2012.917                                           84.87882
# 2012.917                                          306.59470
# 2013.583                                          561.98450
# 2013.500                                          561.98450
# 2012.833                                          390.56840
# ...                                                     ...
# ...

# %%
DF.describe
# Out:
# <bound method NDFrame.describe of                       No  X2 house age  \
# X1 transaction date
# 2012.917               1          32.0
# 2012.917               2          19.5
# 2013.583               3          13.3
# 2013.500               4          13.3
# 2012.833               5           5.0
# ...                  ...           ...
# 2013.000             410          13.7
# 2012.667             411           5.6
# 2013.250             412          18.8
# 2013.000             413           8.1
# 2013.500             414           6.5
#
#                      X3 distance to the nearest MRT station  \
# X1 transaction date
# 2012.917                                           84.87882
# 2012.917                                          306.59470
# 2013.583                                          561.98450
# 2013.500                                          561.98450
# 2012.833                                          390.56840
# ...

# %%
book = pd.read_csv("Downloads\dataset\Book.csv")

# %%
book
# Out:
#       area     price  No of rooms  Age of House  No of floars Locality
# 0   2600.0  550000.0          5.0          20.0           2.0    urban
# 1   3000.0  565000.0          4.0          21.0           1.0    rural
# 2   3200.0  610000.0          6.0          25.0           2.0    urban
# 3   3600.0  680000.0          8.0          10.0           3.0    urban
# 4   4000.0  725000.0          NaN           5.0           1.0    urban
# 5   4400.0  750000.0          6.0           8.0           3.0      NaN
# 6   4200.0  650000.0          8.0           NaN           3.0    urban
# 7   4150.0  645000.0          4.0          12.0           NaN    rural
# 8   3500.0       NaN          4.0          15.0           1.0    rural
# 9      NaN  500000.0          NaN          22.0           4.0    urban
# 10  4050.0  805000.0          6.0           4.0           2.0      NaN

# %%
new_B = book.fillna(0)
new_B
# Out:
#       area     price  No of rooms  Age of House  No of floars Locality
# 0   2600.0  550000.0          5.0          20.0           2.0    urban
# 1   3000.0  565000.0          4.0          21.0           1.0    rural
# 2   3200.0  610000.0          6.0          25.0           2.0    urban
# 3   3600.0  680000.0          8.0          10.0           3.0    urban
# 4   4000.0  725000.0          0.0           5.0           1.0    urban
# 5   4400.0  750000.0          6.0           8.0           3.0        0
# 6   4200.0  650000.0          8.0           0.0           3.0    urban
# 7   4150.0  645000.0          4.0          12.0           0.0    rural
# 8   3500.0       0.0          4.0          15.0           1.0    rural
# 9      0.0  500000.0          0.0          22.0           4.0    urban
# 10  4050.0  805000.0          6.0           4.0           2.0        0

# %%
new_B = book.fillna({
    'price': 550000,
    'No of rooms':6,
    'Age of House':5,
    'No of floars':1,
    'Locality':'rural'
})
new_B # using dictionary to handle missing values
# Out:
#       area     price  No of rooms  Age of House  No of floars Locality
# 0   2600.0  550000.0          5.0          20.0           2.0    urban
# 1   3000.0  565000.0          4.0          21.0           1.0    rural
# 2   3200.0  610000.0          6.0          25.0           2.0    urban
# 3   3600.0  680000.0          8.0          10.0           3.0    urban
# 4   4000.0  725000.0          6.0           5.0           1.0    urban
# 5   4400.0  750000.0          6.0           8.0           3.0    rural
# 6   4200.0  650000.0          8.0           5.0           3.0    urban
# 7   4150.0  645000.0          4.0          12.0           1.0    rural
# 8   3500.0  550000.0          4.0          15.0           1.0    rural
# 9      NaN  500000.0          6.0          22.0           4.0    urban
# 10  4050.0  805000.0          6.0           4.0           2.0    rural

# %%
new_b = book.fillna(method='ffill') #forward fill method
# new_b = book.fillna(method='bfill') is backward fill

# %%
new_b
# Out:
#       area     price  No of rooms  Age of House  No of floars Locality
# 0   2600.0  550000.0          5.0          20.0           2.0    urban
# 1   3000.0  565000.0          4.0          21.0           1.0    rural
# 2   3200.0  610000.0          6.0          25.0           2.0    urban
# 3   3600.0  680000.0          8.0          10.0           3.0    urban
# 4   4000.0  725000.0          8.0           5.0           1.0    urban
# 5   4400.0  750000.0          6.0           8.0           3.0    urban
# 6   4200.0  650000.0          8.0           8.0           3.0    urban
# 7   4150.0  645000.0          4.0          12.0           3.0    rural
# 8   3500.0  645000.0          4.0          15.0           1.0    rural
# 9   3500.0  500000.0          4.0          22.0           4.0    urban
# 10  4050.0  805000.0          6.0           4.0           2.0    urban

# %%
new_b = book.fillna(method='bfill',axis = 'columns')
# new_b = book.fillna(method='bfill',limit = 1) setting copying value limit
new_b
# Out:
#         area     price No of rooms Age of House No of floars Locality
# 0     2600.0  550000.0         5.0         20.0          2.0    urban
# 1     3000.0  565000.0         4.0         21.0          1.0    rural
# 2     3200.0  610000.0         6.0         25.0          2.0    urban
# 3     3600.0  680000.0         8.0         10.0          3.0    urban
# 4     4000.0  725000.0         5.0          5.0          1.0    urban
# 5     4400.0  750000.0         6.0          8.0          3.0      NaN
# 6     4200.0  650000.0         8.0          3.0          3.0    urban
# 7     4150.0  645000.0         4.0         12.0        rural    rural
# 8     3500.0       4.0         4.0         15.0          1.0    rural
# 9   500000.0  500000.0        22.0         22.0          4.0    urban
# 10    4050.0  805000.0         6.0          4.0          2.0      NaN

# %%
new_B = book.interpolate()
# new_B = book.interpolate(method = 'time') gives values considering time also 
new_B
# Out:
#       area     price  No of rooms  Age of House  No of floars Locality
# 0   2600.0  550000.0          5.0          20.0           2.0    urban
# 1   3000.0  565000.0          4.0          21.0           1.0    rural
# 2   3200.0  610000.0          6.0          25.0           2.0    urban
# 3   3600.0  680000.0          8.0          10.0           3.0    urban
# 4   4000.0  725000.0          7.0           5.0           1.0    urban
# 5   4400.0  750000.0          6.0           8.0           3.0      NaN
# 6   4200.0  650000.0          8.0          10.0           3.0    urban
# 7   4150.0  645000.0          4.0          12.0           2.0    rural
# 8   3500.0  572500.0          4.0          15.0           1.0    rural
# 9   3775.0  500000.0          5.0          22.0           4.0    urban
# 10  4050.0  805000.0          6.0           4.0           2.0      NaN

# %%
new_S = book.dropna(thresh=6) # threshold gives the no of valid values we want to consider 
new_S
# Out:
#      area     price  No of rooms  Age of House  No of floars Locality
# 0  2600.0  550000.0          5.0          20.0           2.0    urban
# 1  3000.0  565000.0          4.0          21.0           1.0    rural
# 2  3200.0  610000.0          6.0          25.0           2.0    urban
# 3  3600.0  680000.0          8.0          10.0           3.0    urban

# %%
import numpy as np
new_D = book.replace(6,np.NaN)
# new_D = book.replace([6,8,5],np.NaN) will replace all 6,8,5 values with NaN
new_D
# Out:
#       area     price  No of rooms  Age of House  No of floars Locality
# 0   2600.0  550000.0          5.0          20.0           2.0    urban
# 1   3000.0  565000.0          4.0          21.0           1.0    rural
# 2   3200.0  610000.0          NaN          25.0           2.0    urban
# 3   3600.0  680000.0          8.0          10.0           3.0    urban
# 4   4000.0  725000.0          NaN           5.0           1.0    urban
# 5   4400.0  750000.0          NaN           8.0           3.0      NaN
# 6   4200.0  650000.0          8.0           NaN           3.0    urban
# 7   4150.0  645000.0          4.0          12.0           NaN    rural
# 8   3500.0       NaN          4.0          15.0           1.0    rural
# 9      NaN  500000.0          NaN          22.0           4.0    urban
# 10  4050.0  805000.0          NaN           4.0           2.0      NaN
