# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-de75ca21-7d12-4d7b-8adc-8a6304e7a2b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de75ca21-7d12-4d7b-8adc-8a6304e7a2b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving amazon_jobs_dataset.csv to amazon_jobs_dataset.csv

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv('amazon_jobs_dataset.csv')
date = np.array(df['Posting_date'])
city = np.array(df['location'])
print(date)
# Out:
# ['March  1, 2018' 'March  1, 2018' 'March  1, 2018' ... 'March  6, 2012'
#  'November 28, 2011' 'July  7, 2011']

# %%
year = []
for item in date:
    year.append(item[-4:])
year = np.array(year)
print(year[:50])
# Out:
# ['2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018'
#  '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018'
#  '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018'
#  '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018'
#  '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018' '2018']

# %%
numOfPosting = {}
for item in year:
    if numOfPosting.get(item, 0) == 0:
        numOfPosting[item] = 1
    else:
        numOfPosting[item] += 1
        
for key, value in sorted(numOfPosting.items()):
    print("{} {}".format(key, value))
# Out:
# 2011 2
# 2012 7
# 2013 3
# 2014 5
# 2015 29
# 2016 123
# 2017 1614
# 2018 1710

# %%
lists = sorted(numOfPosting.items())
x, y = zip(*lists)
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv('amazon_jobs_dataset.csv')
date = np.array(df['Posting_date'])
# df['City'] = df['location'].apply(lambda x: x.split(',')[2])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=pd.read_csv('amazon_jobs_dataset.csv',encoding='utf-8')
location=data['location'].str.split(', ',expand=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=pd.read_csv('amazon_jobs_dataset.csv',encoding='utf-8')
location=data['location'].str.split(', ',expand=True)
arr=location[0]=='IN'
india_city=location[arr][2]
freq=india_city.value_counts()
plt.axis("equal")
x=freq.index
plt.pie(freq,labels=x,autopct='%.2f%%')
plt.show()
perc=np.true_divide(freq,freq.sum(axis=0))*100
for i in range(len(x)):
    print(x[i],format(perc[i],'.2f'))
# Out:
# Bangalore  46.81
# Hyderabad  25.53
# Chennai  23.40
# Gurgaon  3.55
# Pune  0.71

# %%
import numpy as np
import matplotlib.pyplot as plt
x =[0,1,2,3,4,5,6,7,9,10]
y= [1,2,5,10,17,26,37,50,82,101]

plt.plot(x, y)
p = np.interp(9, x,y)
print(p)
# Out:
# 82.0

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,40,2)
y = 2 ** x
plt.plot(x, y,'b--')
print(35)
# Out:
# 35
