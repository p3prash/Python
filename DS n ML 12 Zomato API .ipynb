# %%
from google.colab import files
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json

# %matplotlib inline

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94ecbb9e-b0f8-479d-b08a-1148365a4a2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94ecbb9e-b0f8-479d-b08a-1148365a4a2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-4-ed2fd71b4a2f> in <module>()
# ----> 1 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      61   result = _output.eval_js(
#      62       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 63           input_id=input_id, output_id=output_id))
# ...
